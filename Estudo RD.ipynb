# %%
import pandas as pd

# %%
df = pd.read_csv('bi_challenge_rd_bi_funnel_email.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                  id                             email  \
# 0  6dc60743324c1cf3b1a7e885a342584e  a420a5f6b1e671ad2c1b81f5a81c588c
# 1  303e7afd55b9c83671832e8727f803de  ef5dee33403c15cc26af267d290bf93c
# 2  2e1f2e19c14df0869fe232b2e93384dd  48d6dcee60fe6677c55e1e4de904a278
# 3  1f2525d8ae56b4e160ecd810ee7240d2  cddd941ca5822851786800bad19d7b7f
# 4  5e61d3bddf2897611558b54f215d59bf  ebdb6f0f3921582d0e0f10d3936a2f85
#
#   created_month         created_date lead_created_month    lead_created_date  \
# 0    2018-11-01  2018-11-14 15:36:03         2018-11-01  2018-11-14 15:36:03
# 1    2018-11-01  2018-11-20 10:32:01         2018-11-01  2018-11-20 10:32:01
# 2    2018-12-01  2018-12-06 15:14:59         2018-12-01  2018-12-06 15:14:59
# 3    2018-11-01  2018-11-07 02:57:19         2018-11-01  2018-11-07 02:57:19
# 4    2018-11-01  2018-11-22 15:35:01         2018-11-01  2018-11-22 15:35:01
#
#   mql_created_month     mql_created_date sal_created_month sal_created_date  \
# ...

# %%
df.count()
# Out:
# id                        22933
# email                     22933
# created_month             22933
# created_date              22933
# lead_created_month        22933
# lead_created_date         22933
# mql_created_month          3520
# mql_created_date           3437
# sal_created_month          1155
# sal_created_date           1119
# first_touch_date          22933
# last_touch_date           22933
# account_first_touch       22933
# account_last_touch        22933
# channel_first_touch       22933
# channel_last_touch        22933
# campaign_first_touch      20384
# campaign_last_touch       22493
# identifier_first_touch    22933
# identifier_last_touch     22933
# icp_score                 22933
# lead_channel              22933
# lead_type                 22933
# country                   22932
# is_new_lead               22933
# converted_to_mql          22933
# is_blank_mql              22933
# converted_to_sal          22933
# is_a                      22933
# ...

# %%
df.describe(include='all')
# Out:
#                                       id                             email  \
# count                              22933                             22933
# unique                             22933                             21240
# top     22583be1292e686dae6f6aac53e2788d  9e881550b7e266d2c37b40952b884490
# freq                                   1                                 2
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        created_month         created_date lead_created_month  \
# ...

# %%
df.created_month.value_counts()
# Out:
# 2018-11-01    13398
# 2018-12-01     9535
# Name: created_month, dtype: int64

# %%
df.lead_created_month.value_counts()
# Out:
# 2018-11-01    13398
# 2018-12-01     9535
# Name: lead_created_month, dtype: int64

# %%
df.mql_created_month.value_counts()
# Out:
# 2018-11-01    2043
# 2018-12-01    1477
# Name: mql_created_month, dtype: int64

# %%
df.sal_created_month.value_counts()
# Out:
# 2018-11-01    695
# 2018-12-01    460
# Name: sal_created_month, dtype: int64

# %%
df.account_first_touch.value_counts()
# Out:
# Brasil       14464
# Latam         5774
# Partners      2340
# Portugal       319
# Spain           35
# Worldwide        1
# Name: account_first_touch, dtype: int64

# %%
df.account_last_touch.value_counts()
# Out:
# Brasil      13736
# Latam        5845
# Partners     3018
# Portugal      334
# Name: account_last_touch, dtype: int64

# %%
df.channel_first_touch.value_counts()
# Out:
# Email             13762
# Paid Search        3082
# Organic Search     1501
# Direct             1484
# Unknown            1047
# Referral            829
# (Other)             758
# Social              468
# Display               2
# Name: channel_first_touch, dtype: int64

# %%
df.channel_last_touch.value_counts()
# Out:
# Email    22933
# Name: channel_last_touch, dtype: int64

# %%
df.identifier_first_touch.value_counts()
# Out:
# 2324dd747554bb7f8ac53cb91842976c    1107
# 84e9fb9e65e3e3fe6b56412df0f51279     782
# 9f5c22907685035ec9b4cbe80e9a89e0     757
# 9e200b1294b13d0d7d0eea37030b68f3     713
# c8de5cdf6dd0affa9ff766aef54d61a5     618
# 643571e919832046a3c33167660191f2     526
# a0e6dab88c1af71ef5f321e207bfd6d5     484
# d30f2e8cecc1498b3466860a9b7e05c7     425
# a6a62db21af6c8a915976e238bb6d227     421
# bf5af30b7afd3276ebddac6df51b0e5c     355
# b6d53f55ec9cf7c8d05966195488e7ef     346
# 001a9de20472b57900f1ba26569e506d     339
# 414a357b38b8e181ed557d328417a52c     334
# 40c2d2269db7f7993a68c0cd4e87f385     328
# 4cf674ecdc70fb035b775e815c4db5f9     320
# ddc0f3cdfc488fa0a6f6bd02291eb443     320
# 20617c34c561a1112e31f1399356bc7a     301
# 26e8d2b82e436c98f02f9a378ed6ee12     290
# 331e7316df37a1bf038cc0907ee1b7e2     286
# afba56f67eaa6decc3c358ec2fc46e90     273
# 4f08880d2b4f4c4bf848c6c2c0b4c8f6     264
# ea5e2573bfff9713710cff080b805412     255
# 4e84dc61c1acaf32af94a7c3f3612e43     250
# ...

# %%
df.identifier_last_touch.value_counts()
# Out:
# 2324dd747554bb7f8ac53cb91842976c    1767
# 9e200b1294b13d0d7d0eea37030b68f3    1442
# c8de5cdf6dd0affa9ff766aef54d61a5    1309
# 9f5c22907685035ec9b4cbe80e9a89e0    1184
# d30f2e8cecc1498b3466860a9b7e05c7     868
# f8cb4fbb2ad1e566251ff28a98615a5a     776
# ddc0f3cdfc488fa0a6f6bd02291eb443     718
# a6a62db21af6c8a915976e238bb6d227     698
# afba56f67eaa6decc3c358ec2fc46e90     678
# 56fd1e0c5925450c9a665411367101bf     612
# a0e6dab88c1af71ef5f321e207bfd6d5     565
# 331e7316df37a1bf038cc0907ee1b7e2     508
# b6d53f55ec9cf7c8d05966195488e7ef     495
# 83cbd569703ccd9e3e6f802a1b761f1c     365
# 087cb68478b8fb7d6ec150f76dab86ed     363
# 40c2d2269db7f7993a68c0cd4e87f385     355
# 502c278aef815a027b0c5f4919d07f47     349
# 3872e330741b4ea1b3397bd31447cba0     335
# 414a357b38b8e181ed557d328417a52c     305
# 4cf674ecdc70fb035b775e815c4db5f9     303
# bf5af30b7afd3276ebddac6df51b0e5c     296
# addab103ca342880f743063d6e81aad3     274
# 871fa13f222c321c2ce977e740db99da     267
# ...

# %%
df.icp_score.value_counts()
# Out:
# D    12762
# B     4448
# C     3006
# A     2717
# Name: icp_score, dtype: int64

# %%
df.lead_channel.value_counts()
# Out:
# Inbound    17401
# Partner     5532
# Name: lead_channel, dtype: int64

# %%
df.lead_type.value_counts()
# Out:
# MQL            22661
# HR               270
# Indicação          1
# Chat Online        1
# Name: lead_type, dtype: int64

# %%
df.country.value_counts()
# Out:
# BR         15642
# MX          1907
# CO          1739
# Unknown     1410
# AR           851
# ES           322
# PT           199
# VE           131
# CL           119
# PE            88
# US            83
# EC            62
# AO            50
# CR            45
# GT            38
# PY            34
# MZ            33
# PA            33
# BO            20
# UY            19
# HN            14
# IT            10
# CA             9
# JP             8
# AU             7
# CV             7
# SV             6
# FR             6
# DO             5
# CH             5
# GB             4
# TH             4
# SE             3
# IE             3
# PR             2
# HU             2
# NZ             2
# MT             1
# NL             1
# RO             1
# LU             1
# IL             1
# BE             1
# DE             1
# CU             1
# ID             1
# NI             1
# Name: country, dtype: int64

# %%
print(df.dtypes)
# Out:
# id                        object
# email                     object
# created_month             object
# created_date              object
# lead_created_month        object
# lead_created_date         object
# mql_created_month         object
# mql_created_date          object
# sal_created_month         object
# sal_created_date          object
# first_touch_date          object
# last_touch_date           object
# account_first_touch       object
# account_last_touch        object
# channel_first_touch       object
# channel_last_touch        object
# campaign_first_touch      object
# campaign_last_touch       object
# identifier_first_touch    object
# identifier_last_touch     object
# icp_score                 object
# lead_channel              object
# lead_type                 object
# country                   object
# is_new_lead                int64
# converted_to_mql           int64
# is_blank_mql               int64
# converted_to_sal           int64
# ...

# %%
df.head()
# Out:
#                                  id                             email  \
# 0  6dc60743324c1cf3b1a7e885a342584e  a420a5f6b1e671ad2c1b81f5a81c588c
# 1  303e7afd55b9c83671832e8727f803de  ef5dee33403c15cc26af267d290bf93c
# 2  2e1f2e19c14df0869fe232b2e93384dd  48d6dcee60fe6677c55e1e4de904a278
# 3  1f2525d8ae56b4e160ecd810ee7240d2  cddd941ca5822851786800bad19d7b7f
# 4  5e61d3bddf2897611558b54f215d59bf  ebdb6f0f3921582d0e0f10d3936a2f85
#
#   created_month         created_date lead_created_month    lead_created_date  \
# 0    2018-11-01  2018-11-14 15:36:03         2018-11-01  2018-11-14 15:36:03
# 1    2018-11-01  2018-11-20 10:32:01         2018-11-01  2018-11-20 10:32:01
# 2    2018-12-01  2018-12-06 15:14:59         2018-12-01  2018-12-06 15:14:59
# 3    2018-11-01  2018-11-07 02:57:19         2018-11-01  2018-11-07 02:57:19
# 4    2018-11-01  2018-11-22 15:35:01         2018-11-01  2018-11-22 15:35:01
#
#   mql_created_month     mql_created_date sal_created_month sal_created_date  \
# ...
